# %% [markdown]
# ## Introduction to Stats in Python Studio
#
# We are going to be working with this [dataset](https://www.kaggle.com/andrewmvd/heart-failure-clinical-data) from Kaggle.  No need to download, as it is included in the git repository you just cloned.
# <br>
#
# Heart Disease is the number 1 cause of death globally, taking an estimated 17.9 million lives each year, which accounts for 31% of all deaths worldwide.
# <br>
#
# Heart failure is a common event caused by heart disease and this dataset contains 12 features that can be used to predict mortality by heart failure. You are tasked to look at two particular variables and record your observations about their usefulness for predicting the probability of heart failure.
# <br>
#
# In section one, you will be asked to run some simple EDA and apply statistical terminology to describe each variable in more detail.  Section two will explore what the distribution of your variables looks like. Finally, in section three you will be asked to make some inferences about your variables and if you feel they are good indicators of predicting heart failure.
# <br>
#
# Answer the questions and record your observations in the space provided. Feel free to add more code blocks if you'd like.
# <br>

# %% [raw]
# Description of Data:
#
# Sex - Gender of patient Male = 1, Female =0
# Age - Age of patient
# Diabetes - 0 = No, 1 = Yes
# Anaemia - 0 = No, 1 = Yes
# High_blood_pressure - 0 = No, 1 = Yes
# Smoking - 0 = No, 1 = Yes
# DEATH_EVENT - 0 = No, 1 = Yes

# %%
# Import libries need with alias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')


# Set style and font size
sns.set_style('darkgrid')
sns.set(font_scale=1.5)

# %%
# Read in data to a dataframe
df = pd.read_csv('heart3.csv')

# %% [markdown]
# ## Section 1: First look at the data:
#
# Run some simple EDA and look at the data and your variables. Answer the following questions.

# %%
import pandas as pd
df = pd.read_csv('heart3.csv')

df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %%
df[['age','diabetes']].groupby(['age']).describe()
# Out:
#        diabetes
#           count      mean       std  min   25%  50%   75%  max
# age
# 40.000      7.0  0.285714  0.487950  0.0  0.00  0.0  0.50  1.0
# 41.000      1.0  0.000000       NaN  0.0  0.00  0.0  0.00  0.0
# 42.000      7.0  0.285714  0.487950  0.0  0.00  0.0  0.50  1.0
# 43.000      1.0  0.000000       NaN  0.0  0.00  0.0  0.00  0.0
# 44.000      2.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0
# 45.000     19.0  0.578947  0.507257  0.0  0.00  1.0  1.00  1.0
# 46.000      3.0  0.333333  0.577350  0.0  0.00  0.0  0.50  1.0
# 47.000      1.0  0.000000       NaN  0.0  0.00  0.0  0.00  0.0
# 48.000      2.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0
# 49.000      4.0  0.250000  0.500000  0.0  0.00  0.0  0.25  1.0
# 50.000     27.0  0.444444  0.506370  0.0  0.00  0.0  1.00  1.0
# 51.000      4.0  0.500000  0.577350  0.0  0.00  0.5  1.00  1.0
# 52.000      5.0  0.400000  0.547723  0.0  0.00  0.0  1.00  1.0
# 53.000     10.0  0.300000  0.483046  0.0  0.00  0.0  0.75  1.0
# 54.000      2.0  0.500000  0.707107  0.0  0.25  0.5  0.75  1.0
# 55.000     17.0  0.235294  0.437237  0.0  0.00  0.0  0.00  1.0
# 56.000      1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0
# 57.000      2.0  0.000000  0.000000  0.0  0.00  0.0  0.00  0.0
# 58.000     10.0  0.500000  0.527046  0.0  0.00  0.5  1.00  1.0
# 59.000      4.0  0.750000  0.500000  0.0  0.75  1.0  1.00  1.0
# 60.000     33.0  0.575758  0.501890  0.0  0.00  1.0  1.00  1.0
# 60.667      2.0  1.000000  0.000000  1.0  1.00  1.0  1.00  1.0
# 61.000      4.0  0.500000  0.577350  0.0  0.00  0.5  1.00  1.0
# 62.000      5.0  0.600000  0.547723  0.0  0.00  1.0  1.00  1.0
# 63.000      8.0  0.500000  0.534522  0.0  0.00  0.5  1.00  1.0
# 64.000      3.0  0.000000  0.000000  0.0  0.00  0.0  0.00  0.0
# 65.000     26.0  0.576923  0.503831  0.0  0.00  1.0  1.00  1.0
# 66.000      2.0  0.500000  0.707107  0.0  0.25  0.5  0.75  1.0
# 67.000      2.0  0.000000  0.000000  0.0  0.00  0.0  0.00  0.0
# 68.000      5.0  0.400000  0.547723  0.0  0.00  0.0  1.00  1.0
# 69.000      3.0  0.333333  0.577350  0.0  0.00  0.0  0.50  1.0
# 70.000     25.0  0.360000  0.489898  0.0  0.00  0.0  1.00  1.0
# 72.000      7.0  0.285714  0.487950  0.0  0.00  0.0  0.50  1.0
# 73.000      4.0  0.250000  0.500000  0.0  0.00  0.0  0.25  1.0
# 75.000     11.0  0.272727  0.467099  0.0  0.00  0.0  0.50  1.0
# 77.000      2.0  0.000000  0.000000  0.0  0.00  0.0  0.00  0.0
# 78.000      2.0  0.000000  0.000000  0.0  0.00  0.0  0.00  0.0
# 79.000      1.0  0.000000       NaN  0.0  0.00  0.0  0.00  0.0
# 80.000      7.0  0.428571  0.534522  0.0  0.00  0.0  1.00  1.0
# 81.000      1.0  0.000000       NaN  0.0  0.00  0.0  0.00  0.0
# 82.000      3.0  0.666667  0.577350  0.0  0.50  1.0  1.00  1.0
# 85.000      6.0  0.000000  0.000000  0.0  0.00  0.0  0.00  0.0
# 86.000      1.0  0.000000       NaN  0.0  0.00  0.0  0.00  0.0
# 87.000      1.0  0.000000       NaN  0.0  0.00  0.0  0.00  0.0
# 90.000      3.0  0.333333  0.577350  0.0  0.00  0.0  0.50  1.0
# 94.000      1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0
# 95.000      2.0  0.000000  0.000000  0.0  0.00  0.0  0.00  0.0

# %% [markdown]
# Which of our columns are catogorical data?
# <BR><BR><BR> sex, age, diabetes, anaemia, high blood pressure, smoking, death event
#
# Which of our columns are continuous?
# <BR><BR><BR> creatinine, ejection fraction, platelets, serum creatinine, serum sodium

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %% [markdown]
# ### Statistical interpretation of our data?
# #### First Variable:
# Mean, Min, Max, STD? Describe what this means.
#
# <br><br><br>
# Mean : 60
# Min : 40
# Max : 95
# STD : 11
#
# So average age is 60, the minimum age is 40, the maximum age is 95, and the standard deviation is 11 years.
#
# #### Second Variable:
# Mean, Min, Max, STD? Describe what this means.
#
# <br><br><br>
# Mean : 0.42
# Min : 0
# Max : 1
# STD : 0.42
#
# This means basically nothing in this case due to the only answers being 0 -No and 1 - Yes
# What could the numbers in our categorical data tell us?
# 0 = no , 1 = yes
# <br><br><br>
#
# Why might we want to keep our categorical data as 1's and 0's? Why may we want to use something like the code below to change it?
#
# The 0's and 1's are cohesive through many columns so it could be easier to search, but if we want it to make more logical sense to whoever is viewing the data we'd want the rows to just say what 0 and 1 means.

# %%
#df['sex'] = df.sex.replace({1: "Male", 0: "Female"})
#df['anaemia'] = df.anaemia.replace({1: "Yes", 0: "No"})
#df['diabetes'] = df.diabetes.replace({1: "Yes", 0: "No"})
#df['high_blood_pressure'] = df.high_blood_pressure.replace({1: "Yes", 0: "No"})
#df['smoking'] = df.smoking.replace({1: "Yes", 0: "No"})

#df['DEATH_EVENT'] = df.DEATH_EVENT.replace({1: "Died", 0: "Alive"})

# %% [markdown]
# ## Section 2: Distribution of our data:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
sns.set_style('darkgrid')
sns.set(font_scale=1.5)
df = pd.read_csv('heart3.csv')

# Plot the distribution of your variable using distplot
sns.distplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
# Create boxplot to show distribution of variable
fig, ax = plt.subplots(figsize=(14,8))
ax.set_ylabel('diabetes')
_ = df[['age','diabetes']].boxplot(by='diabetes', figsize=(13,8))

# %%
# Feel free to add any additional graphs that help you answer the questions below.

# %%
# Another way to check the skewness of our variable
df['age'].skew()
# Out:
# 0.42306190672863536

# %%
df['diabetes'].skew()
# Out:
# 0.3339286842537603

# %%
# Another way to check the kurtosis of our variable
df['age'].kurtosis()
# Out:
# -0.18487053195417413

# %%
df['diabetes'].kurtosis()
# Out:
# -1.901254232288715

# %% [markdown]
# ### Interpretation of how our data is distributed by variable?
# Looking at the above graphs, what can you tell about the distribution of your variables?
# <br><br><br><br><br>
# Most ages are between 40-70, while it goes signficantly down after.
# What is the skewness and kurtosis of your variables.  What does this mean?<br>
# <br><br><br><br><br>
# Skewness we are looking pretty symmetrical for both variables.
# Kurtosis is very low as well so there are a very low frequency of outliers.
# What are some of the differences you note looking at a categorical variable vs a continuous variable?
# <br><br><br><br><br>
# I do not have any continuous variables, but with diabetes being only yes or no there are a lot less outliers than age as well as less of a skew.

# %% [markdown]
# ## Section 3: Finding Correlations
#
# Lets start by breaking our data into two.

# %%
# splitting the dataframe into 2 parts
# on basis of ‘DEATH_EVENT’ column values
import pandas as pd

df = pd.read_csv('heart3.csv')

df_died = df[df['DEATH_EVENT'] == 1 ]
df_lived = df[df['DEATH_EVENT'] == 0 ]

# %%
# Plot your variable based on if they died or lived

sns.distplot(df_died['diabetes'])
sns.distplot(df_lived['diabetes'])
plt.title("Chances of survival vs Diabetes")
plt.legend(('Died','Lived'))
plt.plot()
# Out:
# []

# %%
sns.distplot(df_died['age'])
sns.distplot(df_lived['age'])
plt.title("Chances of survival vs Age")
plt.legend(('Died','Lived'))
plt.plot()
# Out:
# []

# %%
# Feel free to add any additional graphs that help you answer the questions below.

# %% [markdown]
# #### What things can you infer if we consider our data a sample of the population, based on each of your variables.
# <br><br><br><br><br>
# #### Do you think either of your variables is a good indicator for predicting Heart Failure, why or why not?
# <br><br><br><br><br>
#
# No, I don't believe so I don't think we can super accurately gauge heart failurer from just age and if the person has diabetes.
